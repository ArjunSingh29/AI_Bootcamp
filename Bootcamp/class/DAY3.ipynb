# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# ==========================================
# 1. CREATE DATASET
# ==========================================

data = {
    "study_hours": [2, 3, 4, 5, 6, 7, 8, 9, 3, 4,
                    6, 7, 5, 2, 8, 4, 6, 9, 3, 7],

    "attendance": [60, 65, 70, 75, 80, 85, 90, 95, 68, 72,
                   78, 88, 76, 55, 92, 66, 84, 96, 62, 86],

    "assignment": [55, 60, 65, 70, 75, 80, 85, 90, 62, 68,
                   74, 82, 72, 50, 88, 60, 78, 94, 58, 80],

    "result": ["Fail", "Fail", "Fail", "Pass", "Pass",
               "Pass", "Pass", "Pass", "Fail", "Fail",
               "Pass", "Pass", "Pass", "Fail", "Pass",
               "Fail", "Pass", "Pass", "Fail", "Pass"]
}

# Convert data into DataFrame
df = pd.DataFrame(data)

print("========== DATASET ==========")
print(df)

# ==========================================
# 2. SELECT INPUT AND OUTPUT
# ==========================================

X = df[["study_hours", "attendance", "assignment"]]
y = df["result"]

print("\nX shape:", X.shape)
print("y shape:", y.shape)

# ==========================================
# 3. TRAIN-TEST SPLIT
# ==========================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("\n========== TRAIN TEST SPLIT ==========")
print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)

# ==========================================
# 4. CREATE DECISION TREE MODEL
# ==========================================

model = DecisionTreeClassifier(
    random_state=42,
    max_depth=3
)

# ==========================================
# 5. TRAIN THE MODEL
# ==========================================

model.fit(X_train, y_train)

print("\nModel training completed!")

# ==========================================
# 6. PREDICT TEST DATA
# ==========================================

y_pred = model.predict(X_test)

print("\n========== PREDICTION ==========")

print("Actual Results:")
print(y_test.values)

print("\nPredicted Results:")
print(y_pred)

# ==========================================
# 7. CHECK ACCURACY
# ==========================================

accuracy = accuracy_score(y_test, y_pred)

print("\n========== MODEL ACCURACY ==========")
print("Accuracy:", accuracy)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# ==========================================
# 8. PREDICT A NEW STUDENT
# ==========================================

new_student = pd.DataFrame({
    "study_hours": [6],
    "attendance": [82],
    "assignment": [78]
})

prediction = model.predict(new_student)

print("\n========== NEW STUDENT PREDICTION ==========")

print("Study Hours:", new_student["study_hours"].iloc[0])
print("Attendance:", new_student["attendance"].iloc[0], "%")
print("Assignment:", new_student["assignment"].iloc[0])

print("\nPredicted Result:", prediction[0])
# Out:
# ========== DATASET ==========
#     study_hours  attendance  assignment result
# 0             2          60          55   Fail
# 1             3          65          60   Fail
# 2             4          70          65   Fail
# 3             5          75          70   Pass
# 4             6          80          75   Pass
# 5             7          85          80   Pass
# 6             8          90          85   Pass
# 7             9          95          90   Pass
# 8             3          68          62   Fail
# 9             4          72          68   Fail
# 10            6          78          74   Pass
# 11            7          88          82   Pass
# 12            5          76          72   Pass
# 13            2          55          50   Fail
# 14            8          92          88   Pass
# 15            4          66          60   Fail
# 16            6          84          78   Pass
# 17            9          96          94   Pass
# ...
